# %%
print("Hello Ai")
# Out:
# Hello Ai

# %%
print('Júlio Gabriel Rodrigues Simões')
# Out:
# Júlio Gabriel Rodrigues Simões

# %%
nome = 'Júlio Gabriel'
sobrenome = 'Rodrigues Simões'
altura = 1.78
idade = 21
print(nome, sobrenome, 'e tenho', idade, 'anos!')
print(altura, 'altura')
print('Esté é meu nome e minha idade!')
# Out:
# Júlio Gabriel Rodrigues Simões e tenho 21 anos!
# 1.78 altura
# Esté é meu nome e minha idade!

# %%
nome = input('Digte o seu nome: ')
idade = input('Digite a sua idade: ')
print('Seu nome é', nome, 'e sua idade é', idade, 'anos!')
# Out:
# Digte o seu nome: Júlio
# Digite a sua idade: 21
# Seu nome é Júlio e sua idade é 21 anos!

# %%
#Trabalhando com F-String
nome = input('Digte o seu nome: ')
idade = input('Digite a sua idade: ')
#F-String
print(f'Seu nome é {nome} e sua idade é {idade} anos!')
# Out:
# Digte o seu nome: Júlio
# Digite a sua idade: 21
# Seu nome é Júlio e sua idade é 21 anos!

# %%
nome =input('Qual é seu nome: ')
idade = input('Qual é a sua idade: ')
fruta_favorita = input('Qual é sua fruta favorita: ')

print(f'Seu nome é {nome}, você tem {idade} anos e sua fruta favorita é {fruta_favorita}!')
# Out:
# Qual é seu nome: julio
# Qual é a sua idade: 21
# Qual é sua fruta favorita: laranja
# Seu nome é julio, você tem 21 anos e sua fruta favorita é laranja!

# %%
#soma
nome = input('Digite o seu nome: ')
idade = int(input('Qual é sua idade: '))

print(f'Seu nome é {nome} e sua idade é {idade} e daqui a 5 anos você terá {idade + 5} anos!')
# Out:
# Digite o seu nome: julio
# Qual é sua idade: 21
# Seu nome é julio e sua idade é 21 e daqui a 5 anos você terá 26 anos!

# %%
#aritmética
numero1 = 10
numero2 = 2

print(numero1 + numero2)#soma
print(numero1 - numero2)#subtracao
print(numero1 * numero2)#multiplicacao
print(numero1 / numero2)#divisao
print(numero1 // numero2)#divisao inteira
print(numero1 % numero2)#resto da divisao
print(numero1 ** numero2)#potencia
# Out:
# 12
# 8
# 20
# 5.0
# 5
# 0
# 100

# %%
#calcular valor de desconto
preco = float(input('Digite o valor do produto: R$'))
desconto = float(input('Digite a porcentagem do desconto: '))

valor_desconto = preco - (preco * desconto / 100)
print(f'O valor com desconto é R${valor_desconto}')
# Out:
# Digite o valor do produto: R$200
# Digite a porcentagem do desconto: 15
# O valor com desconto é R$170.0

# %%
#DASAFIO
#Calcular quantos dias um produto duraria se a pessoa usar X porções por dia
produto = int(input('Quantas porções esse produto tem? '))
quantidade_dia = int(input('Qiantas porções você irá usar por dia? '))

dias = produto / quantidade_dia

print(f'Esse produto durará {dias:.0f} dias!')
# Out:
# Quantas porções esse produto tem? 300
# Qiantas porções você irá usar por dia? 5
# Esse produto durará 60 dias!

# %%
#Operações Relacionais
numero1 = 10
numero2 = 10

print(numero1 == numero2) #igual
print(numero1 != numero2) #diferente
print(numero1 > numero2) #maior
print(numero1 < numero2) #menor
print(numero1 >= numero2) #maior ou igual
print(numero1 <= numero2) #menor ou igual
# Out:
# True
# False
# False
# False
# True
# True

# %%
#Igual ou maior que 18 anos é adulto
idade = int(input('Digite sua idade: '))

if idade >= 18:
    print('Você é adulto!')
else:
    print('Você é menor de idade')
# Out:
# Digite sua idade: 18
# Você é adulto!

# %%
nota_aluno = int(input('Digite a nota do aluno: '))

if nota_aluno >= 7:
    print('Aprovado')
elif nota_aluno >= 5:
    print('Recuperação')
else:
    print('Reprovado')
# Out:
# Digite a nota do aluno: 10
# Aprovado

# %%
#repetições com for

for i in range(6):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
#While
i = int(input('Digite um número: '))

while i <= 5:
  print(i)
  i += 1
# Out:
# Digite um número: 1
# 1
# 2
# 3
# 4
# 5

# %%
senha = ''
while senha != '123':
  senha = input('Digite a senha: ')
  if senha != '123':
    print('Senha incorreta!')
  else:
   print('Acesso liberado!')
# Out:
# Digite a senha: 1234
# Senha incorreta!
# Digite a senha: 123
# Acesso liberado!

# %%
#Listas de Frutas
frutas = ['Abacate', 'Banana', 'Morango']

frutas.append('Uva')#adicionar
frutas.append('Laranja')

frutas.remove('Banana')#remover

print(len(frutas))#tamanho da lista


print(frutas)
# Out:
# 4
# ['Abacate', 'Morango', 'Uva', 'Laranja']

# %%
#Lista de Tarefas
tarefas = []

tarefas.append('Estudar python com IA')
tarefas.append('Ler artigo IA')
tarefas.append('Responder e-mail')

print('====================================')
print('Minhas tarefas de hoje!')
print('====================================')

for tarefas in tarefas:
  print(tarefas)
# Out:
# ...
# Minhas tarefas de hoje!
# ...
# Estudar python com IA
# Ler artigo IA
# Responder e-mail

# %%
#Tuplas

meses = ('Janeiro', 'Fevereiro', 'Março', 'Abril', 'Maio', 'Junho', 'Julho', 'Agosto', 'Setembro', 'Outubro', 'Novembro', 'Dezembro')

print(meses)
# Out:
# ('Janeiro', 'Fevereiro', 'Março', 'Abril', 'Maio', 'Junho', 'Julho', 'Agosto', 'Setembro', 'Outubro', 'Novembro', 'Dezembro')

# %%
#Dicionarios

usuario = {
    'Nome' : 'Julio',
    'Idade' : 21,
    'Departamento' : 'TI'
}

usuario ['Idade'] = 25 #Atualiza key(chave)
usuario ['Cidade'] = 'Perdizes' #Adicionar
print(usuario)
# Out:
# {'Nome': 'Julio', 'Idade': 25, 'Departamento': 'TI', 'Cidade': 'Perdizes'}

# %%
#Dicionario Aluno
aluno = {
    'nome': input('Digite o nome do aluno: '),
    'idade': int(input('Digite a idade do aluno: ')),
    'nota': float(input('Digite a nota do aluno: '))
}
print('===================================================================')
print(f'{aluno['nome']} tem {aluno['idade']} anose tirou {aluno['nota']} na prova!')
print('===================================================================')
# Out:
# Digite o nome do aluno: Júlio
# Digite a idade do aluno: 21
# Digite a nota do aluno: 9
# ...
# Júlio tem 21 anose tirou 9.0 na prova!
# ...

# %%
#Função
def saudacao(nome, idade):
  print(f'Olá {nome}! Você tem {idade}!')

saudacao('Julio', 21)
# Out:
# Olá Julio! Você tem 21!

# %%
#Função Somar

def somar(num1, num2):
  return num1 + num2

resultado = somar(10, 20)
print(f'O resultado da soma é: {resultado}')
# Out:
# O resultado da soma é: 30

# %%
#Calcular porcentagem
def calcular_porcentagem(preco, porcentagem):
  return  preco -(preco * porcentagem / 100)

preco = float(input('Digite o valor: '))
porcentagem = float(input('Digite a porcentagem: '))

calcular_porcentagem = calcular_porcentagem(preco, porcentagem)

print(f'O valor com desconto é: {calcular_porcentagem:.2f}')
# Out:
# Digite o valor: 100
# Digite a porcentagem: 10
# O valor com desconto é: 90.00
